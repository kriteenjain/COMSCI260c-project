# %%
# =========================
# Cell 1: Clone project
# =========================
# !git clone https://github.com/kriteenjain/COMSCI260c-project.git
# %cd COMSCI260c-project
# Out:
# Cloning into 'COMSCI260c-project'...
# remote: Enumerating objects: 120, done.
# remote: Counting objects: 100% (120/120), done.
# remote: Compressing objects: 100% (83/83), done.
# Receiving objects: 100% (120/120), 90.46 KiB | 753.00 KiB/s, done.
# remote: Total 120 (delta 67), reused 84 (delta 34), pack-reused 0 (from 0)
# Resolving deltas: 100% (67/67), done.
# /content/COMSCI260c-project

# %%
# !rm -rf /content/COMSCI260c-project

# %%
# =========================
# Cell 2: Install deps
# =========================
# !python -m pip install -U pip
# !pip install -r requirements.txt
# !pip install -U "huggingface_hub[hf_transfer]"
# Out:
# ...
# WARNING: huggingface-hub 1.17.0 does not provide the extra 'hf-transfer'
# ...

# %%
# =========================
# Cell 5: Pull latest changes
# =========================
import os
import subprocess

os.chdir("/content/COMSCI260c-project") # Ensure we are in the repository directory
print("Pulling latest changes from the repository...")
subprocess.run(["git", "pull"], check=True)
print("Repository updated.")
# Out:
# Pulling latest changes from the repository...
# Repository updated.

# %%
# =========================
# Cell 3: HF login + env
# =========================
import os
from google.colab import userdata
from huggingface_hub import login, whoami

# Pull token from Colab Secrets (key icon in left sidebar → HF_TOKEN)
# If the secret isn't set, falls back to interactive prompt.
try:
    token = userdata.get('HF_TOKEN')
    login(token=token)
except Exception:
    login()  # interactive prompt fallback

# Expose token to subprocesses so !python run_baseline.py inherits it
os.environ["HF_TOKEN"] = token if 'token' in dir() else ""
os.environ["HF_HOME"] = "/content/.hf_cache"
os.environ["HF_HUB_ENABLE_HF_TRANSFER"] = "1"  # faster downloads

print(whoami()["name"], "— authenticated ✓")
# Out:
# seanhoffy — authenticated ✓

# %%
# =========================
# Cell 4 (optional): verify GPU
# =========================
import torch
print("torch:", torch.__version__)
print("cuda available:", torch.cuda.is_available())
if torch.cuda.is_available():
    print("gpu:", torch.cuda.get_device_name(0))
# Out:
# torch: 2.11.0+cu128
# cuda available: True
# gpu: Tesla T4

# %%
# =========================
# Cell 6: Bigger baseline
# =========================
# !python run_baseline.py --preset llama-3b --task humaneval --limit 20 --batch-size 1 --tag llama3b-baseline20
# Out:
# [load] meta-llama/Llama-3.2-3B-Instruct
# config.json: 100% 878/878 [00:00<00:00, 3.83MB/s]
# tokenizer_config.json: 100% 54.5k/54.5k [00:00<00:00, 12.5MB/s]
# tokenizer.json: 100% 9.09M/9.09M [00:01<00:00, 7.49MB/s]
# special_tokens_map.json: 100% 296/296 [00:00<00:00, 1.63MB/s]
# `torch_dtype` is deprecated! Use `dtype` instead!
# model.safetensors.index.json: 100% 20.9k/20.9k [00:00<00:00, 38.0MB/s]
# ...
# Fetching 2 files: 100% 2/2 [00:56<00:00, 28.28s/it]
# Download complete: 100% 6.43G/6.43G [00:56<00:00, 113MB/s]
# Loading weights: 100% 254/254 [00:00<00:00, 488.57it/s, Materializing param=model.norm.weight]
# generation_config.json: 100% 189/189 [00:00<00:00, 969kB/s]
# [load] device=cuda dtype=torch.bfloat16 n_params=3,212,749,824
# /content/COMSCI260c-project/run_baseline.py:81: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
# ...

# %%
# !python run_baseline.py --preset llama-3b --task gsm8k --limit 20 --batch-size 1 --tag llama3b-baseline20
# Out:
# [load] meta-llama/Llama-3.2-3B-Instruct
# `torch_dtype` is deprecated! Use `dtype` instead!
# Loading weights: 100% 254/254 [00:00<00:00, 737.14it/s, Materializing param=model.norm.weight]
# [load] device=cuda dtype=torch.bfloat16 n_params=3,212,749,824
# /content/COMSCI260c-project/run_baseline.py:81: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   "started_at": dt.datetime.utcnow().isoformat() + "Z",
# README.md: 100% 7.93k/7.93k [00:00<00:00, 2.17MB/s]
# main/train-00000-of-00001.parquet: 100% 2.31M/2.31M [00:01<00:00, 1.62MB/s]
# main/test-00000-of-00001.parquet: 100% 419k/419k [00:00<00:00, 1.01MB/s]
# Generating train split: 100% 7473/7473 [00:00<00:00, 77276.86 examples/s]
# Generating test split: 100% 1319/1319 [00:00<00:00, 189611.23 examples/s]
# gsm8k: 100% 20/20 [04:00<00:00, 12.04s/it]
# ...

# %%
# Qwen baseline — MuSiQue
# !python run_baseline.py --preset qwen-1.5b --task musique --limit 20 --batch-size 4 --tag qwen-baseline20
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/constants.py:277: FutureWarning: The `HF_HUB_ENABLE_HF_TRANSFER` environment variable is deprecated as 'hf_transfer' is not used anymore. Please use `HF_XET_HIGH_PERFORMANCE` instead to enable high performance transfer with Xet. Visit https://huggingface.co/docs/huggingface_hub/package_reference/environment_variables#hfxethighperformance for more details.
#   warnings.warn(
# [load] Qwen/Qwen2.5-1.5B-Instruct
# `torch_dtype` is deprecated! Use `dtype` instead!
# Loading weights: 100% 338/338 [00:00<00:00, 871.46it/s, Materializing param=model.norm.weight]
# [load] device=cuda dtype=torch.bfloat16 n_params=1,543,714,304
# /content/COMSCI260c-project/run_baseline.py:81: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   "started_at": dt.datetime.utcnow().isoformat() + "Z",
# ...

# %%
# LLaMA baseline — MuSiQue
# !python run_baseline.py --preset llama-3b --task musique --limit 20 --batch-size 1 --tag llama3b-baseline20
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/constants.py:277: FutureWarning: The `HF_HUB_ENABLE_HF_TRANSFER` environment variable is deprecated as 'hf_transfer' is not used anymore. Please use `HF_XET_HIGH_PERFORMANCE` instead to enable high performance transfer with Xet. Visit https://huggingface.co/docs/huggingface_hub/package_reference/environment_variables#hfxethighperformance for more details.
#   warnings.warn(
# [load] meta-llama/Llama-3.2-3B-Instruct
# config.json: 100% 878/878 [00:00<00:00, 4.34MB/s]
# tokenizer_config.json: 100% 54.5k/54.5k [00:00<00:00, 69.1MB/s]
# tokenizer.json: 100% 9.09M/9.09M [00:00<00:00, 30.5MB/s]
# special_tokens_map.json: 100% 296/296 [00:00<00:00, 1.99MB/s]
# `torch_dtype` is deprecated! Use `dtype` instead!
# model.safetensors.index.json: 100% 20.9k/20.9k [00:00<00:00, 53.9MB/s]
# ...
# Fetching 2 files: 100% 2/2 [01:08<00:00, 34.47s/it]
# Download complete: 100% 6.43G/6.43G [01:09<00:00, 93.1MB/s]
# ...

# %%
# Qwen baseline — NQ Open
# !python run_baseline.py --preset qwen-1.5b --task nq_open --limit 20 --batch-size 4 --tag qwen-nqopen20
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/constants.py:277: FutureWarning: The `HF_HUB_ENABLE_HF_TRANSFER` environment variable is deprecated as 'hf_transfer' is not used anymore. Please use `HF_XET_HIGH_PERFORMANCE` instead to enable high performance transfer with Xet. Visit https://huggingface.co/docs/huggingface_hub/package_reference/environment_variables#hfxethighperformance for more details.
#   warnings.warn(
# [load] Qwen/Qwen2.5-1.5B-Instruct
# `torch_dtype` is deprecated! Use `dtype` instead!
# Loading weights: 100% 338/338 [00:00<00:00, 940.26it/s, Materializing param=model.norm.weight]
# [load] device=cuda dtype=torch.bfloat16 n_params=1,543,714,304
# /content/COMSCI260c-project/run_baseline.py:81: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   "started_at": dt.datetime.utcnow().isoformat() + "Z",
# ...

# %%
# LLaMA baseline — NQ Open
# !python run_baseline.py --preset llama-3b --task nq_open --limit 20 --batch-size 1 --tag llama3b-nqopen20
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/constants.py:277: FutureWarning: The `HF_HUB_ENABLE_HF_TRANSFER` environment variable is deprecated as 'hf_transfer' is not used anymore. Please use `HF_XET_HIGH_PERFORMANCE` instead to enable high performance transfer with Xet. Visit https://huggingface.co/docs/huggingface_hub/package_reference/environment_variables#hfxethighperformance for more details.
#   warnings.warn(
# [load] meta-llama/Llama-3.2-3B-Instruct
# `torch_dtype` is deprecated! Use `dtype` instead!
# Loading weights: 100% 254/254 [00:00<00:00, 682.34it/s, Materializing param=model.norm.weight]
# [load] device=cuda dtype=torch.bfloat16 n_params=3,212,749,824
# /content/COMSCI260c-project/run_baseline.py:81: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
# ...

# %%
# Qwen baseline - Squad
# !python run_baseline.py --preset qwen-1.5b --task squad --limit 20 --batch-size 4 --tag qwen-squad20
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/constants.py:277: FutureWarning: The `HF_HUB_ENABLE_HF_TRANSFER` environment variable is deprecated as 'hf_transfer' is not used anymore. Please use `HF_XET_HIGH_PERFORMANCE` instead to enable high performance transfer with Xet. Visit https://huggingface.co/docs/huggingface_hub/package_reference/environment_variables#hfxethighperformance for more details.
#   warnings.warn(
# [load] Qwen/Qwen2.5-1.5B-Instruct
# `torch_dtype` is deprecated! Use `dtype` instead!
# Loading weights: 100% 338/338 [00:00<00:00, 536.45it/s, Materializing param=model.norm.weight]
# [load] device=cuda dtype=torch.bfloat16 n_params=1,543,714,304
# /content/COMSCI260c-project/run_baseline.py:81: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   "started_at": dt.datetime.utcnow().isoformat() + "Z",
# ...

# %%
# LLaMA baseline - Squad
# !python run_baseline.py --preset llama-3b --task squad --limit 20 --batch-size 1 --tag llama3b-squad20
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/constants.py:277: FutureWarning: The `HF_HUB_ENABLE_HF_TRANSFER` environment variable is deprecated as 'hf_transfer' is not used anymore. Please use `HF_XET_HIGH_PERFORMANCE` instead to enable high performance transfer with Xet. Visit https://huggingface.co/docs/huggingface_hub/package_reference/environment_variables#hfxethighperformance for more details.
#   warnings.warn(
# [load] meta-llama/Llama-3.2-3B-Instruct
# `torch_dtype` is deprecated! Use `dtype` instead!
# Loading weights: 100% 254/254 [00:00<00:00, 824.07it/s, Materializing param=model.norm.weight]
# [load] device=cuda dtype=torch.bfloat16 n_params=3,212,749,824
# /content/COMSCI260c-project/run_baseline.py:81: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
# ...

# %%
# =========================
# Cell 7: Show results
# =========================
# !ls -lt results
# Out:
# total 280
# -rw-r--r-- 1 root root   5063 Jun  2 04:41 20260602-044135_llama3b-baseline20_meta-llama_Llama-3.2-3B-Instruct.json
# -rw-r--r-- 1 root root   8163 Jun  2 04:15 20260602-041556_qwen-baseline20_Qwen_Qwen2.5-1.5B-Instruct.json
# -rw-r--r-- 1 root root 123155 Jun  2 04:01 20260524-054804_wanda-2-4_Qwen_Qwen2.5-1.5B-Instruct.json
# -rw-r--r-- 1 root root  20164 Jun  2 04:01 20260524-070816_awq-w4g128_Qwen_Qwen2.5-1.5B-Instruct.json
# -rw-r--r-- 1 root root  11987 Jun  2 04:01 llama_gsm8k_baseline.json
# -rw-r--r-- 1 root root   9352 Jun  2 04:01 llama_humaneval_baseline.json
# -rw-r--r-- 1 root root  29270 Jun  2 04:01 Qwen_gsm8k_baseline.json
# -rw-r--r-- 1 root root   6217 Jun  2 04:01 Qwen_humaneval_baseline.json
# -rw-r--r-- 1 root root  56056 Jun  2 04:01 20260524-050441_wanda-u50_Qwen_Qwen2.5-1.5B-Instruct.json

# %%
# =========================
# Cell 8: Download latest JSON
# =========================
import glob
from google.colab import files

paths = sorted(glob.glob("results/20260523-235324_colab-he20-leftpad_Qwen_Qwen2.5-1.5B-Instruct.json"))
latest = paths[-1]
print("Latest:", latest)
files.download(latest)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_1044/2401078355.py in <cell line: 0>()
#       6
#       7 paths = sorted(glob.glob("results/20260523-235324_colab-he20-leftpad_Qwen_Qwen2.5-1.5B-Instruct.json"))
# ----> 8 latest = paths[3]
#       9 print("Latest:", latest)
#      10 files.download(latest)
#
# IndexError: list index out of range

# %%
# Optional: Configure your Git identity if you haven't already
# !git config --global user.email "kriteenjain@gmail.com"
# !git config --global user.name "kriteenjain"

# Add the results file to staging
# !git add -f {latest}

# Commit the changes
# !git commit -m "Add new baseline results: {latest.split('/')[-1]}"

# Push the changes to the remote repository (e.g., 'origin main')
# You might need to authenticate here, depending on your setup.
# !git push origin main
# Out:
# fatal: pathspec '{latest}' did not match any files
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean
# fatal: could not read Username for 'https://github.com': No such device or address

# %%
import os, getpass, subprocess, glob

os.chdir("/content/COMSCI260c-project")

# set git identity once for this Colab session
subprocess.run(["git", "config", "user.email", "kriteenjain@gmail.com"], check=True)
subprocess.run(["git", "config", "user.name", "kriteenjain"], check=True)

# add latest result
latest = sorted(glob.glob("results/*.json"))[-1]
subprocess.run(["git", "add", "-f", latest], check=True)

# Check if there's anything to commit before committing
status_output = subprocess.run(["git", "status", "--porcelain"], capture_output=True, text=True, check=True).stdout.strip()
if status_output:
    subprocess.run(["git", "commit", "-m", f"Add baseline result: {os.path.basename(latest)}"], check=True)
else:
    print("No new changes to commit.")

# PAT push
user = "kriteenjain"
pat = getpass.getpass("GitHub PAT (repo scope): ")
auth_url = f"https://{user}:{pat}@github.com/kriteenjain/COMSCI260c-project.git"

subprocess.run(["git", "remote", "set-url", "origin", auth_url], check=True)
subprocess.run(["git", "push", "origin", "main"], check=True)

# clean token from remote URL after push
subprocess.run(["git", "remote", "set-url", "origin", "https://github.com/kriteenjain/COMSCI260c-project.git"], check=True)

print("Pushed:", latest)
# Out:
# No new changes to commit.
# GitHub PAT (repo scope): ··········
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# /tmp/ipykernel_1044/4252325823.py in <cell line: 0>()
#      24
#      25 subprocess.run(["git", "remote", "set-url", "origin", auth_url], check=True)
# ---> 26 subprocess.run(["git", "push", "origin", "main"], check=True)
#      27
#      28 # clean token from remote URL after push
#
# /usr/lib/python3.12/subprocess.py in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     569         retcode = process.poll()
#     570         if check and retcode:
# --> 571             raise CalledProcessError(retcode, process.args,
#     572                                      output=stdout, stderr=stderr)
#     573     return CompletedProcess(process.args, retcode, stdout, stderr)
#
# ...

# %% [markdown]
# #LLAMA

# %%
# 1) Fresh auth in this runtime
from huggingface_hub import login, whoami
import os, getpass

token = getpass.getpass("HF token: ")
login(token=token, add_to_git_credential=False)

# 2) Force token into subprocess env too
os.environ["HF_TOKEN"] = token
os.environ["HUGGING_FACE_HUB_TOKEN"] = token
os.environ["HF_HOME"] = "/content/.hf_cache"

print(whoami())
# Out:
# HF token: ··········
# Note: Environment variable`HF_TOKEN` is set and is the current active token independently from the token you've just configured.
# WARNING:huggingface_hub._login:Note: Environment variable`HF_TOKEN` is set and is the current active token independently from the token you've just configured.
# {'type': 'user', 'id': '6a1e06fbfa591b0b2cc599a4', 'name': 'seanhoffy', 'fullname': 'Sean Hoffmeister', 'email': 'seanhoffy@g.ucla.edu', 'emailVerified': True, 'canPay': False, 'billingMode': 'prepaid', 'periodEnd': 1782864000, 'isPro': False, 'avatarUrl': '/avatars/96ee80c5db915f1eb729d1673830228c.svg', 'orgs': [], 'auth': {'type': 'access_token', 'accessToken': {'displayName': '260C_Project_Token', 'role': 'read', 'createdAt': '2026-06-01T22:39:04.904Z'}}}
